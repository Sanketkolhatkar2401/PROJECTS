# %%
# !pip install mysql-connector
# !pip install --upgrade mysql-connector-python

# %%
import mysql.connector
import pandas as pd
import seaborn as sns

# %%
db = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "Sanket@12",
    database = "customer_st1",
    auth_plugin = 'mysql_native_password'
)

mycursor = db.cursor()

print(db)

# %%
mycursor.execute("select * from product")

output = mycursor.fetchall()

for X in output:
    print(X)
# Out:
# (1, 'Laptop', 'Electronics', Decimal('899.99'), 50, '15-inch display, 8GB RAM, 256GB SSD')
# (2, 'Smartphone', 'Electronics', Decimal('699.99'), 120, '6.5-inch display, 128GB storage')
# (3, 'Headphones', 'Electronics', Decimal('149.99'), 200, 'Noise-cancelling over-ear headphones')
# (4, 'Desk Chair', 'Furniture', Decimal('199.99'), 80, 'Ergonomic office chair with lumbar support')
# (5, 'Coffee Table', 'Furniture', Decimal('89.99'), 60, 'Wooden coffee table with glass top')
# (6, 'Running Shoes', 'Footwear', Decimal('129.99'), 100, 'Lightweight running shoes for men and women')
# (7, 'Backpack', 'Accessories', Decimal('49.99'), 150, 'Water-resistant backpack with multiple compartments')
# (8, 'Wristwatch', 'Accessories', Decimal('199.99'), 75, 'Stainless steel wristwatch with leather strap')
# (9, 'Blender', 'Appliances', Decimal('59.99'), 85, 'High-speed blender with multiple settings')
# ...

# %%
query = "select * from product"

df = pd.read_sql(query,db)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_15068\4175273792.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query,db)

# %%
df.head()
# Out:
#    product_id  product_name     category   price  stock_quantity  \
# 0           1        Laptop  Electronics  899.99              50
# 1           2    Smartphone  Electronics  699.99             120
# 2           3    Headphones  Electronics  149.99             200
# 3           4    Desk Chair    Furniture  199.99              80
# 4           5  Coffee Table    Furniture   89.99              60
#
#                                   description
# 0         15-inch display, 8GB RAM, 256GB SSD
# 1             6.5-inch display, 128GB storage
# 2        Noise-cancelling over-ear headphones
# 3  Ergonomic office chair with lumbar support
# 4          Wooden coffee table with glass top

# %%
df.tail()
# Out:
#     product_id    product_name     category   price  stock_quantity  \
# 15          16  Gaming Console  Electronics  399.99              35
# 16          17       Bookshelf    Furniture  129.99              50
# 17          18         T-shirt      Apparel   19.99             200
# 18          19           Jeans      Apparel   49.99             180
# 19          20          Jacket      Apparel   89.99              60
#
#                                     description
# 15     Next-gen gaming console with 1TB storage
# 16              Wooden bookshelf with 5 shelves
# 17  Cotton t-shirt available in multiple colors
# 18                  Denim jeans with a slim fit
# 19                Waterproof jacket with a hood

# %%
df.isna().sum()
# Out:
# product_id        0
# product_name      0
# category          0
# price             0
# stock_quantity    0
# description       0
# dtype: int64

# %%
df.isna()
# Out:
#     product_id  product_name  category  price  stock_quantity  description
# 0        False         False     False  False           False        False
# 1        False         False     False  False           False        False
# 2        False         False     False  False           False        False
# 3        False         False     False  False           False        False
# 4        False         False     False  False           False        False
# 5        False         False     False  False           False        False
# 6        False         False     False  False           False        False
# 7        False         False     False  False           False        False
# 8        False         False     False  False           False        False
# 9        False         False     False  False           False        False
# 10       False         False     False  False           False        False
# ...

# %%
df.describe()
# Out:
#        product_id       price  stock_quantity
# count    20.00000   20.000000       20.000000
# mean     10.50000  226.490000       90.750000
# std       5.91608  231.386553       55.042448
# min       1.00000   19.990000       20.000000
# 25%       5.75000   89.990000       50.000000
# 50%      10.50000  139.990000       77.500000
# 75%      15.25000  224.990000      120.000000
# max      20.00000  899.990000      200.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      20 non-null     int64
#  1   product_name    20 non-null     object
#  2   category        20 non-null     object
#  3   price           20 non-null     float64
#  4   stock_quantity  20 non-null     int64
#  5   description     20 non-null     object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.1+ KB

# %%
df.shape
# Out:
# (20, 6)

# %%
df.isnull()
# Out:
#     product_id  product_name  category  price  stock_quantity  description
# 0        False         False     False  False           False        False
# 1        False         False     False  False           False        False
# 2        False         False     False  False           False        False
# 3        False         False     False  False           False        False
# 4        False         False     False  False           False        False
# 5        False         False     False  False           False        False
# 6        False         False     False  False           False        False
# 7        False         False     False  False           False        False
# 8        False         False     False  False           False        False
# 9        False         False     False  False           False        False
# 10       False         False     False  False           False        False
# ...

# %%
df['price']
# Out:
# 0     899.99
# 1     699.99
# 2     149.99
# 3     199.99
# 4      89.99
# 5     129.99
# 6      49.99
# 7     199.99
# 8      59.99
# 9     129.99
# 10    499.99
# 11    299.99
# 12     99.99
# 13    149.99
# 14    179.99
# 15    399.99
# 16    129.99
# 17     19.99
# 18     49.99
# 19     89.99
# Name: price, dtype: float64

# %%
df[['product_name', 'stock_quantity']].head(20)
# Out:
#       product_name  stock_quantity
# 0           Laptop              50
# 1       Smartphone             120
# 2       Headphones             200
# 3       Desk Chair              80
# 4     Coffee Table              60
# 5    Running Shoes             100
# 6         Backpack             150
# 7       Wristwatch              75
# 8          Blender              85
# 9   Microwave Oven              40
# 10          LED TV              30
# 11    Dining Table              20
# 12        Sneakers             120
# 13         Handbag              90
# 14  Vacuum Cleaner              70
# 15  Gaming Console              35
# 16       Bookshelf              50
# 17         T-shirt             200
# 18           Jeans             180
# 19          Jacket              60

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'price', 'stock_quantity',
#        'description'],
#       dtype='object')

# %%
df[df.index==2]
# Out:
#    product_id product_name     category   price  stock_quantity  \
# 2           3   Headphones  Electronics  149.99             200
#
#                             description
# 2  Noise-cancelling over-ear headphones

# %%
df[df.index.isin(range(3,10))]
# Out:
#    product_id    product_name     category   price  stock_quantity  \
# 3           4      Desk Chair    Furniture  199.99              80
# 4           5    Coffee Table    Furniture   89.99              60
# 5           6   Running Shoes     Footwear  129.99             100
# 6           7        Backpack  Accessories   49.99             150
# 7           8      Wristwatch  Accessories  199.99              75
# 8           9         Blender   Appliances   59.99              85
# 9          10  Microwave Oven   Appliances  129.99              40
#
#                                          description
# 3         Ergonomic office chair with lumbar support
# 4                 Wooden coffee table with glass top
# 5        Lightweight running shoes for men and women
# 6  Water-resistant backpack with multiple compart...
# 7      Stainless steel wristwatch with leather strap
# 8          High-speed blender with multiple settings
# 9        Compact microwave oven with digital display

# %%
df.iloc[5]
# Out:
# product_id                                                  6
# product_name                                    Running Shoes
# category                                             Footwear
# price                                                  129.99
# stock_quantity                                            100
# description       Lightweight running shoes for men and women
# Name: 5, dtype: object

# %%
df.dropna().head(10).tail(10)
# Out:
#    product_id    product_name     category   price  stock_quantity  \
# 0           1          Laptop  Electronics  899.99              50
# 1           2      Smartphone  Electronics  699.99             120
# 2           3      Headphones  Electronics  149.99             200
# 3           4      Desk Chair    Furniture  199.99              80
# 4           5    Coffee Table    Furniture   89.99              60
# 5           6   Running Shoes     Footwear  129.99             100
# 6           7        Backpack  Accessories   49.99             150
# 7           8      Wristwatch  Accessories  199.99              75
# 8           9         Blender   Appliances   59.99              85
# 9          10  Microwave Oven   Appliances  129.99              40
#
#                                          description
# 0                15-inch display, 8GB RAM, 256GB SSD
# 1                    6.5-inch display, 128GB storage
# 2               Noise-cancelling over-ear headphones
# ...

# %%
mean_value = df['stock_quantity'].mean()
mean_value
# Out:
# 90.75

# %%
df.fillna(mean_value).head(8)
# Out:
#    product_id   product_name     category   price  stock_quantity  \
# 0           1         Laptop  Electronics  899.99              50
# 1           2     Smartphone  Electronics  699.99             120
# 2           3     Headphones  Electronics  149.99             200
# 3           4     Desk Chair    Furniture  199.99              80
# 4           5   Coffee Table    Furniture   89.99              60
# 5           6  Running Shoes     Footwear  129.99             100
# 6           7       Backpack  Accessories   49.99             150
# 7           8     Wristwatch  Accessories  199.99              75
#
#                                          description
# 0                15-inch display, 8GB RAM, 256GB SSD
# 1                    6.5-inch display, 128GB storage
# 2               Noise-cancelling over-ear headphones
# 3         Ergonomic office chair with lumbar support
# 4                 Wooden coffee table with glass top
# ...

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'price', 'stock_quantity',
#        'description'],
#       dtype='object')

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot.scatter(x = 'product_name',y = 'stock_quantity')
# Out:
# <Axes: xlabel='product_name', ylabel='stock_quantity'>

# %%
df.plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.area()
# Out:
# <Axes: >

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot.barh()
# Out:
# <Axes: >

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.plot.hexbin(x = 'price', y = 'stock_quantity',gridsize=18)
# Out:
# <Axes: xlabel='price', ylabel='stock_quantity'>

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'price', 'stock_quantity',
#        'description'],
#       dtype='object')

# %%
df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot.pie(y= 'price',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='price'>

# %%
import seaborn
seaborn.violinplot(x ='price', y ='stock_quantity', data = df)
# Out:
# <Axes: xlabel='price', ylabel='stock_quantity'>

# %%
seaborn.pairplot(df, hue ='price')

# %%
sns.histplot(data = df, x = "stock_quantity", kde = True)
# Out:
# <Axes: xlabel='stock_quantity', ylabel='Count'>
